# %%
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import seaborn as sns

# %%
final_df = pd.read_csv("../half_season/h1_dfs/final_transition_out_of_poss_df_H1.csv")
final_df = final_df.rename(columns={'Unnamed: 0': 'uniqueTeamId'})
team_ids_h1 = final_df['uniqueTeamId']
final_df.set_index("uniqueTeamId", inplace = True)
final_df = final_df.fillna(0)

final_df_h2 = pd.read_csv("../half_season/h2_dfs/final_transition_out_of_poss_df_H2.csv")
final_df_h2 = final_df.rename(columns={'Unnamed: 0': 'uniqueTeamId'}).reset_index()
team_ids_h2 = final_df_h2['uniqueTeamId']
final_df_h2 = final_df_h2.fillna(0)
final_df_h2.set_index("uniqueTeamId", inplace = True)

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import silhouette_score
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans, AgglomerativeClustering
from sklearn.decomposition import PCA
from kmedoids import KMedoids
from pyclustering.cluster.kmedoids import kmedoids
from pyclustering.cluster import cluster_visualizer
from pyclustering.utils import calculate_distance_matrix
import pandas as pd
import numpy as np
import random

import torch
import torch.nn as nn
import torch.optim as optim
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import silhouette_score
from sklearn.cluster import KMeans
import numpy as np
import matplotlib.pyplot as plt

    # Autoencoder for DEC
class Encoder(nn.Module):
    def __init__(self, input_dim, latent_dim=10):
        super().__init__()
        self.model = nn.Sequential(
            nn.Linear(input_dim, 128),
            nn.ReLU(),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Linear(64, latent_dim)
        )

    def forward(self, x):
        return self.model(x)

class Decoder(nn.Module):
    def __init__(self, latent_dim, output_dim):
        super().__init__()
        self.model = nn.Sequential(
            nn.Linear(latent_dim, 64),
            nn.ReLU(),
            nn.Linear(64, 128),
            nn.ReLU(),
            nn.Linear(128, output_dim)
        )

    def forward(self, z):
        return self.model(z)

class AutoEncoder(nn.Module):
    def __init__(self, input_dim, latent_dim=10):
        super().__init__()
        self.encoder = Encoder(input_dim, latent_dim)
        self.decoder = Decoder(latent_dim, input_dim)

    def forward(self, x):
        z = self.encoder(x)
        out = self.decoder(z)
        return out


    # DEC model
class DEC(nn.Module):
    def __init__(self, encoder, cluster_centers):
        super().__init__()
        self.encoder = encoder
        self.clusters = nn.Parameter(cluster_centers)

    def forward(self, x):
        z = self.encoder(x)
        q = 1.0 / (1.0 + torch.sum((z.unsqueeze(1) - self.clusters)**2, dim=2))
        q = q / torch.sum(q, dim=1, keepdim=True)
        return q

# Target distribution
def target_distribution(q):
    weight = q ** 2 / q.sum(0)
    return (weight.t() / weight.sum(1)).t()

from sklearn.metrics import pairwise_distances
from scipy.spatial.distance import cdist

def compute_indices(X, labels):
    n_clusters = len(np.unique(labels))
    cluster_centers = []
    for i in range(n_clusters):
        cluster_points = X[labels == i]
        if len(cluster_points) == 0:
            cluster_centers.append(np.zeros(X.shape[1]))
        else:
            cluster_centers.append(cluster_points.mean(axis=0))
    cluster_centers = np.array(cluster_centers)

    distances = pairwise_distances(X, cluster_centers)

    # Iwcss: Sum of squared distances to cluster centers
    Iwcss = sum(np.sum((X[labels == i] - cluster_centers[i]) ** 2) for i in range(n_clusters))

    # Isep: Mean distance between all cluster centers
    Isep = np.mean(cdist(cluster_centers, cluster_centers))

    # Idistcc and Idens with filtering for valid clusters
    valid_dists = []
    valid_dens = []
    for i in range(n_clusters):
        cluster_points = X[labels == i]
        if len(cluster_points) < 2:
            continue  # Skip small clusters to avoid NaN in mean/std
        distances_to_center = np.linalg.norm(cluster_points - cluster_centers[i], axis=1)
        valid_dists.append(np.mean(distances_to_center))
        valid_dens.append(np.std(distances_to_center))

    # Default to 0 if all clusters were invalid
    Idistcc = np.mean(valid_dists) if valid_dists else 0.0
    Idens = np.mean(valid_dens) if valid_dens else 0.0

    return Iwcss, Isep, Idistcc, Idens



def normalize(val, min_val, max_val, larger_is_better):
    range_ = max_val - min_val
    if np.isclose(range_, 0):
        return 1.0  # or 0.5, depending on how you want to treat flat metrics
    if larger_is_better:
        return np.clip((val - min_val) / (range_ + 1e-10), 0, 1)
    else:
        return np.clip(1 - (val - min_val) / (range_ + 1e-10), 0, 1)

# %%
import random
seed = 42
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)

# If using GPU
torch.cuda.manual_seed(seed)
torch.cuda.manual_seed_all(seed)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

scaler = StandardScaler()
X_h1 = scaler.fit_transform(final_df)          # FIT on H1
X_h2 = scaler.transform(final_df_h2)           # TRANSFORM H2

pca2 = PCA(n_components=2, random_state=42)
X_h1_pca = pca2.fit_transform(X_h1)            # FIT on H1
X_h2_pca = pca2.transform(X_h2)                # TRANSFORM H2

X_h1_tensor = torch.tensor(X_h1, dtype=torch.float32)
X_h2_tensor = torch.tensor(X_h2, dtype=torch.float32)



dec_loss = {}

from sklearn.metrics import pairwise_distances_argmin

def predict_via_centroids(X_train, y_train, X_eval):
    centers = np.vstack([X_train[y_train == c].mean(axis=0) for c in np.unique(y_train)])
    return pairwise_distances_argmin(X_eval, centers)  # nearest center id

# %%
# Store results
results = []

def append_eval(k, method, X_eval, y_eval, split_tag):
    sil = silhouette_score(X_eval, y_eval)
    Iwcss, Isep, Idistcc, Idens = compute_indices(X_eval, y_eval)
    results.append({
        "k": k,
        "method": method,
        "split": split_tag,
        "silhouette_score": sil,
        "Iwcss": Iwcss,
        "Isep": Isep,
        "Idistcc": Idistcc,
        "Idens": Idens
    })

for k in range(2, 11):
    clusterings = {
        "kmeans": KMeans(n_clusters=k, random_state=42),
        "kmedoids": KMedoids(n_clusters=k, metric="euclidean", init="random", max_iter=300, random_state=42),
        "ward": AgglomerativeClustering(n_clusters=k, linkage="ward"),
    }

    # ====== RAW space (scaled) ======
    for method_name, model in clusterings.items():
        y_h1 = model.fit_predict(X_h1)

        # Evaluate on H1
        append_eval(k, method_name, X_h1, y_h1, "H1")

        # Labels for H2 (predict if possible; else centroid assignment)
        if hasattr(model, "predict"):
            y_h2 = model.predict(X_h2)
        else:
            y_h2 = predict_via_centroids(X_h1, y_h1, X_h2)

        # Evaluate on H2
        append_eval(k, method_name, X_h2, y_h2, "H2")

    # ====== PCA space ======
    for method_name, model in clusterings.items():
        y_h1 = model.fit_predict(X_h1_pca)

        append_eval(k, f"{method_name}_pca", X_h1_pca, y_h1, "H1")

        if hasattr(model, "predict"):
            y_h2 = model.predict(X_h2_pca)
        else:
            y_h2 = predict_via_centroids(X_h1_pca, y_h1, X_h2_pca)

        append_eval(k, f"{method_name}_pca", X_h2_pca, y_h2, "H2")

# %%
results
# Out:
# [{'k': 2,
#   'method': 'kmeans',
#   'split': 'H1',
#   'silhouette_score': 0.11251613659032295,
#   'Iwcss': 75713.83689467481,
#   'Isep': 2.1136884732363104,
#   'Idistcc': 6.360737631497658,
#   'Idens': 1.7207091355375712},
#  {'k': 2,
#   'method': 'kmeans',
#   'split': 'H2',
#   'silhouette_score': 0.11251613659032295,
#   'Iwcss': 75713.83689467481,
#   'Isep': 2.1136884732363104,
#   'Idistcc': 6.360737631497658,
#   'Idens': 1.7207091355375712},
#  {'k': 2,
#   'method': 'kmedoids',
#   'split': 'H1',
#   'silhouette_score': 0.05022134824087,
#   'Iwcss': 77915.01402472204,
#   'Isep': 1.5267410363742644,
#   'Idistcc': 6.291445315697015,
#   'Idens': 1.7394621558441645},
#  {'k': 2,
#   'method': 'kmedoids',
#   'split': 'H2',
#   'silhouette_score': 0.05022134824087,
#   'Iwcss': 0.0,
#   'Isep': 0.0,
#   'Idistcc': 0.0,
#   'Idens': 0.0},
#  {'k': 2,
#   'method': 'ward',
#   'split': 'H1',
#   'silhouette_score': 0.06870971696939066,
#   'Iwcss': 77917.47877165356,
#   'Isep': 1.8481533179533203,
#   'Idistcc': 6.286226246418698,
#   'Idens': 1.5790175386271077},
#  {'k': 2,
#   'method': 'ward',
#   'split': 'H2',
#   'silhouette_score': 0.11030768842837889,
#   'Iwcss': 75793.88872444704,
#   'Isep': 2.1430678557032343,
#   'Idistcc': 6.336315614923869,
#   'Idens': 1.653360505089077},
#  {'k': 2,
#   'method': 'kmeans_pca',
#   'split': 'H1',
#   'silhouette_score': 0.3626538925882199,
#   'Iwcss': 12684.647307189822,
#   'Isep': 2.101176319697538,
#   'Idistcc': 2.3756651559519746,
#   'Idens': 1.2572379930164113},
#  {'k': 2,
#   'method': 'kmeans_pca',
#   'split': 'H2',
#   'silhouette_score': 0.3626537230271843,
#   'Iwcss': 12684.649837474744,
#   'Isep': 2.1011759058310195,
#   'Idistcc': 2.3756653755973183,
#   'Idens': 1.2572384574304203},
#  {'k': 2,
#   'method': 'kmedoids_pca',
#   'split': 'H1',
#   'silhouette_score': 0.32720619577257953,
#   'Iwcss': 12879.45402472791,
#   'Isep': 1.8478441803634242,
#   'Idistcc': 2.2814789771100674,
#   'Idens': 1.3597119168905767},
#  {'k': 2,
#   'method': 'kmedoids_pca',
#   'split': 'H2',
#   'silhouette_score': 0.3272061442734618,
#   'Iwcss': 0.0,
#   'Isep': 0.0,
#   'Idistcc': 0.0,
#   'Idens': 0.0},
#  {'k': 2,
#   'method': 'ward_pca',
#   'split': 'H1',
#   'silhouette_score': 0.3774436559799157,
#   'Iwcss': 13226.741079267831,
#   'Isep': 2.323171227864824,
#   'Idistcc': 2.4014414944686147,
#   'Idens': 1.2438687523490468},
#  {'k': 2,
#   'method': 'ward_pca',
#   'split': 'H2',
#   'silhouette_score': 0.37813032451894485,
#   'Iwcss': 12793.550421250222,
#   'Isep': 2.235460726996688,
#   'Idistcc': 2.3748852358935784,
#   'Idens': 1.2385993987564046},
#  {'k': 3,
#   'method': 'kmeans',
#   'split': 'H1',
#   'silhouette_score': 0.07771820083239603,
#   'Iwcss': 70589.81274934411,
#   'Isep': 3.0295837817017537,
#   'Idistcc': 6.08107957404209,
#   'Idens': 1.634463051700979},
#  {'k': 3,
#   'method': 'kmeans',
#   'split': 'H2',
#   'silhouette_score': 0.07771820083239603,
#   'Iwcss': 70589.81274934411,
#   'Isep': 3.0295837817017537,
#   'Idistcc': 6.08107957404209,
#   'Idens': 1.634463051700979},
#  {'k': 3,
#   'method': 'kmedoids',
#   'split': 'H1',
#   'silhouette_score': 0.04287210913141249,
#   'Iwcss': 73730.71350459068,
#   'Isep': 2.545001680373512,
#   'Idistcc': 6.1703356850840665,
#   'Idens': 1.680749857041013},
#  {'k': 3,
#   'method': 'kmedoids',
#   'split': 'H2',
#   'silhouette_score': 0.04287210913141249,
#   'Iwcss': 0.0,
#   'Isep': 0.0,
#   'Idistcc': 0.0,
#   'Idens': 0.0},
#  {'k': 3,
#   'method': 'ward',
#   'split': 'H1',
#   'silhouette_score': 0.03690730735300897,
#   'Iwcss': 75379.96961669141,
#   'Isep': 2.3462913704160973,
#   'Idistcc': 6.182574686402229,
#   'Idens': 1.6865323398206618},
#  {'k': 3,
#   'method': 'ward',
#   'split': 'H2',
#   'silhouette_score': 0.07023846072192405,
#   'Iwcss': 71022.69555943894,
#   'Isep': 2.966621103228741,
#   'Idistcc': 6.065621415643524,
#   'Idens': 1.6413301484822307},
#  {'k': 3,
#   'method': 'kmeans_pca',
#   'split': 'H1',
#   'silhouette_score': 0.3851470810707181,
#   'Iwcss': 7592.395350070863,
#   'Isep': 3.017071137131385,
#   'Idistcc': 1.8854515361262523,
#   'Idens': 0.9244913171789243},
#  {'k': 3,
#   'method': 'kmeans_pca',
#   'split': 'H2',
#   'silhouette_score': 0.3851470682398928,
#   'Iwcss': 7592.393800623177,
#   'Isep': 3.0170713272966942,
#   'Idistcc': 1.8854517350637252,
#   'Idens': 0.9244904915092412},
#  {'k': 3,
#   'method': 'kmedoids_pca',
#   'split': 'H1',
#   'silhouette_score': 0.38059225053934836,
#   'Iwcss': 7649.391647505516,
#   'Isep': 2.9561145899958174,
#   'Idistcc': 1.8701686757608071,
#   'Idens': 0.9218773161212357},
#  {'k': 3,
#   'method': 'kmedoids_pca',
#   'split': 'H2',
#   'silhouette_score': 0.38059210979140246,
#   'Iwcss': 0.0,
#   'Isep': 0.0,
#   'Idistcc': 0.0,
#   'Idens': 0.0},
#  {'k': 3,
#   'method': 'ward_pca',
#   'split': 'H1',
#   'silhouette_score': 0.3657665731085625,
#   'Iwcss': 8013.1283156372765,
#   'Isep': 3.0716527926251422,
#   'Idistcc': 1.9610283325193414,
#   'Idens': 0.9700834402963859},
#  {'k': 3,
#   'method': 'ward_pca',
#   'split': 'H2',
#   'silhouette_score': 0.38396865514782347,
#   'Iwcss': 7630.431297305021,
#   'Isep': 3.065979194506733,
#   'Idistcc': 1.9026510704113424,
#   'Idens': 0.9338042307303485},
#  {'k': 4,
#   'method': 'kmeans',
#   'split': 'H1',
#   'silhouette_score': 0.04722820875816086,
#   'Iwcss': 68927.65628091655,
#   'Isep': 3.2764301907267877,
#   'Idistcc': 5.946871143844322,
#   'Idens': 1.593708896660608},
#  {'k': 4,
#   'method': 'kmeans',
#   'split': 'H2',
#   'silhouette_score': 0.04722820875816086,
#   'Iwcss': 68927.65628091655,
#   'Isep': 3.2764301907267877,
#   'Idistcc': 5.946871143844322,
#   'Idens': 1.593708896660608},
#  {'k': 4,
#   'method': 'kmedoids',
#   'split': 'H1',
#   'silhouette_score': 0.021741201373694275,
#   'Iwcss': 72325.24468899005,
#   'Isep': 2.837453648069598,
#   'Idistcc': 6.04496184479733,
#   'Idens': 1.6759576411024217},
#  {'k': 4,
#   'method': 'kmedoids',
#   'split': 'H2',
#   'silhouette_score': 0.021741201373694275,
#   'Iwcss': 0.0,
#   'Isep': 0.0,
#   'Idistcc': 0.0,
#   'Idens': 0.0},
#  {'k': 4,
#   'method': 'ward',
#   'split': 'H1',
#   'silhouette_score': 0.02143993006413924,
#   'Iwcss': 73432.95726626652,
#   'Isep': 3.2584355530000586,
#   'Idistcc': 6.6742566302949236,
#   'Idens': 1.5092908917470764},
#  {'k': 4,
#   'method': 'ward',
#   'split': 'H2',
#   'silhouette_score': 0.06390502925645532,
#   'Iwcss': 69650.47744025002,
#   'Isep': 3.654924968998558,
#   'Idistcc': 6.626183158441056,
#   'Idens': 1.5086896976868114},
#  {'k': 4,
#   'method': 'kmeans_pca',
#   'split': 'H1',
#   'silhouette_score': 0.356286480810824,
#   'Iwcss': 6189.072912010428,
#   'Isep': 3.415845790509496,
#   'Idistcc': 1.7064243021612961,
#   'Idens': 0.8480663972272522},
#  {'k': 4,
#   'method': 'kmeans_pca',
#   'split': 'H2',
#   'silhouette_score': 0.3562863625047003,
#   'Iwcss': 6189.073641337144,
#   'Isep': 3.415845566834909,
#   'Idistcc': 1.7064248146681429,
#   'Idens': 0.8480663287236282},
#  {'k': 4,
#   'method': 'kmedoids_pca',
#   'split': 'H1',
#   'silhouette_score': 0.35340920282190286,
#   'Iwcss': 6257.875148232608,
#   'Isep': 3.304179406493896,
#   'Idistcc': 1.6955752315383985,
#   'Idens': 0.8599705216318719},
#  {'k': 4,
#   'method': 'kmedoids_pca',
#   'split': 'H2',
#   'silhouette_score': 0.3534090273775023,
#   'Iwcss': 0.0,
#   'Isep': 0.0,
#   'Idistcc': 0.0,
#   'Idens': 0.0},
#  {'k': 4,
#   'method': 'ward_pca',
#   'split': 'H1',
#   'silhouette_score': 0.28471227750565437,
#   'Iwcss': 6840.4428299886,
#   'Isep': 3.0611387879286553,
#   'Idistcc': 1.6823850683736334,
#   'Idens': 0.8215419894713476},
#  {'k': 4,
#   'method': 'ward_pca',
#   'split': 'H2',
#   'silhouette_score': 0.34104133138117154,
#   'Iwcss': 6257.752895329986,
#   'Isep': 3.2908143432359984,
#   'Idistcc': 1.6911703651324246,
#   'Idens': 0.8397239708547991},
#  {'k': 5,
#   'method': 'kmeans',
#   'split': 'H1',
#   'silhouette_score': 0.04712778733824786,
#   'Iwcss': 67563.7670779772,
#   'Isep': 3.647907250395633,
#   'Idistcc': 5.964391804256583,
#   'Idens': 1.6120285187471506},
#  {'k': 5,
#   'method': 'kmeans',
#   'split': 'H2',
#   'silhouette_score': 0.04712778733824786,
#   'Iwcss': 67563.7670779772,
#   'Isep': 3.647907250395633,
#   'Idistcc': 5.964391804256583,
#   'Idens': 1.6120285187471506},
#  {'k': 5,
#   'method': 'kmedoids',
#   'split': 'H1',
#   'silhouette_score': 0.018130612568112502,
#   'Iwcss': 71228.76889888881,
#   'Isep': 3.131073790908238,
#   'Idistcc': 6.010058620491273,
#   'Idens': 1.6449209833432739},
#  {'k': 5,
#   'method': 'kmedoids',
#   'split': 'H2',
#   'silhouette_score': 0.018130612568112502,
#   'Iwcss': 0.0,
#   'Isep': 0.0,
#   'Idistcc': 0.0,
#   'Idens': 0.0},
#  {'k': 5,
#   'method': 'ward',
#   'split': 'H1',
#   'silhouette_score': 0.027772597922236134,
#   'Iwcss': 71590.09790110339,
#   'Isep': 5.347943598039738,
#   'Idistcc': 6.482861029729085,
#   'Idens': 1.4574107618011818},
#  {'k': 5,
#   'method': 'ward',
#   'split': 'H2',
#   'silhouette_score': 0.06969534982027802,
#   'Iwcss': 67821.66265813753,
#   'Isep': 5.618551554356554,
#   'Idistcc': 6.445722535856885,
#   'Idens': 1.4548452335472308},
#  {'k': 5,
#   'method': 'kmeans_pca',
#   'split': 'H1',
#   'silhouette_score': 0.32958875190326287,
#   'Iwcss': 5083.059835581318,
#   'Isep': 3.680969009048029,
#   'Idistcc': 1.5564101754296573,
#   'Idens': 0.7750014267431915},
#  {'k': 5,
#   'method': 'kmeans_pca',
#   'split': 'H2',
#   'silhouette_score': 0.3295887870959074,
#   'Iwcss': 5083.0599198965965,
#   'Isep': 3.6809688585397033,
#   'Idistcc': 1.5564103730302337,
#   'Idens': 0.7750014441432796},
#  {'k': 5,
#   'method': 'kmedoids_pca',
#   'split': 'H1',
#   'silhouette_score': 0.3217667133526678,
#   'Iwcss': 5131.328305106521,
#   'Isep': 3.534626993811571,
#   'Idistcc': 1.5295696519922157,
#   'Idens': 0.7654901092448865},
#  {'k': 5,
#   'method': 'kmedoids_pca',
#   'split': 'H2',
#   'silhouette_score': 0.32176732566240346,
#   'Iwcss': 0.0,
#   'Isep': 0.0,
#   'Idistcc': 0.0,
#   'Idens': 0.0},
#  {'k': 5,
#   'method': 'ward_pca',
#   'split': 'H1',
#   'silhouette_score': 0.2997139823298372,
#   'Iwcss': 5934.449584711041,
#   'Isep': 3.572378868008096,
#   'Idistcc': 1.648702283486037,
#   'Idens': 0.8483544094837872},
#  {'k': 5,
#   'method': 'ward_pca',
#   'split': 'H2',
#   'silhouette_score': 0.33653823003075894,
#   'Iwcss': 5508.0956181624115,
#   'Isep': 3.720302791710259,
#   'Idistcc': 1.6156103669334665,
#   'Idens': 0.8222684518182053},
#  {'k': 6,
#   'method': 'kmeans',
#   'split': 'H1',
#   'silhouette_score': 0.04841051199226339,
#   'Iwcss': 66081.65844228679,
#   'Isep': 5.0173724258326065,
#   'Idistcc': 5.969637241039609,
#   'Idens': 1.4915210547809357},
#  {'k': 6,
#   'method': 'kmeans',
#   'split': 'H2',
#   'silhouette_score': 0.04841051199226339,
#   'Iwcss': 66081.65844228679,
#   'Isep': 5.0173724258326065,
#   'Idistcc': 5.969637241039609,
#   'Idens': 1.4915210547809357},
#  {'k': 6,
#   'method': 'kmedoids',
#   'split': 'H1',
#   'silhouette_score': 0.017895442615413985,
#   'Iwcss': 69986.89124273327,
#   'Isep': 3.3746255059498687,
#   'Idistcc': 6.002156908525596,
#   'Idens': 1.6597396467576988},
#  {'k': 6,
#   'method': 'kmedoids',
#   'split': 'H2',
#   'silhouette_score': 0.017895442615413985,
#   'Iwcss': 0.0,
#   'Isep': 0.0,
#   'Idistcc': 0.0,
#   'Idens': 0.0},
#  {'k': 6,
#   'method': 'ward',
#   'split': 'H1',
#   'silhouette_score': 0.03311006070083649,
#   'Iwcss': 69806.76322687707,
#   'Isep': 6.528781502770748,
#   'Idistcc': 6.476226008277997,
#   'Idens': 1.4016993361614938},
#  {'k': 6,
#   'method': 'ward',
#   'split': 'H2',
#   'silhouette_score': 0.07223070750323099,
#   'Iwcss': 66216.84129370419,
#   'Isep': 6.7320822100717415,
#   'Idistcc': 6.432154445240481,
#   'Idens': 1.3757140343983452},
#  {'k': 6,
#   'method': 'kmeans_pca',
#   'split': 'H1',
#   'silhouette_score': 0.33915816319890896,
#   'Iwcss': 4244.862590484732,
#   'Isep': 3.919633013260631,
#   'Idistcc': 1.4508562285077513,
#   'Idens': 0.6920251751106913},
#  {'k': 6,
#   'method': 'kmeans_pca',
#   'split': 'H2',
#   'silhouette_score': 0.33915834866194483,
#   'Iwcss': 4244.860637193034,
#   'Isep': 3.919633388705556,
#   'Idistcc': 1.45085583970873,
#   'Idens': 0.6920252782502789},
#  {'k': 6,
#   'method': 'kmedoids_pca',
#   'split': 'H1',
#   'silhouette_score': 0.3229325321891579,
#   'Iwcss': 4363.271143042998,
#   'Isep': 3.6232765309006427,
#   'Idistcc': 1.4010919098667245,
#   'Idens': 0.6802936183774478},
#  {'k': 6,
#   'method': 'kmedoids_pca',
#   'split': 'H2',
#   'silhouette_score': 0.322932779536618,
#   'Iwcss': 0.0,
#   'Isep': 0.0,
#   'Idistcc': 0.0,
#   'Idens': 0.0},
#  {'k': 6,
#   'method': 'ward_pca',
#   'split': 'H1',
#   'silhouette_score': 0.2954210213845363,
#   'Iwcss': 5091.035493235074,
#   'Isep': 3.768880494193072,
#   'Idistcc': 1.496198869186057,
#   'Idens': 0.764019380621611},
#  {'k': 6,
#   'method': 'ward_pca',
#   'split': 'H2',
#   'silhouette_score': 0.32316586051995033,
#   'Iwcss': 4654.003961350466,
#   'Isep': 3.9031156478866063,
#   'Idistcc': 1.4646438005716307,
#   'Idens': 0.7359449725376006},
#  {'k': 7,
#   'method': 'kmeans',
#   'split': 'H1',
#   'silhouette_score': 0.0495462133093957,
#   'Iwcss': 64525.60747000561,
#   'Isep': 5.417025980551118,
#   'Idistcc': 5.932604869549975,
#   'Idens': 1.4159444882494863},
#  {'k': 7,
#   'method': 'kmeans',
#   'split': 'H2',
#   'silhouette_score': 0.0495462133093957,
#   'Iwcss': 64525.60747000561,
#   'Isep': 5.417025980551118,
#   'Idistcc': 5.932604869549975,
#   'Idens': 1.4159444882494863},
#  {'k': 7,
#   'method': 'kmedoids',
#   'split': 'H1',
#   'silhouette_score': 0.01715334829556097,
#   'Iwcss': 68476.41996315819,
#   'Isep': 3.6126105575486243,
#   'Idistcc': 5.933811820117951,
#   'Idens': 1.6352081050212688},
#  {'k': 7,
#   'method': 'kmedoids',
#   'split': 'H2',
#   'silhouette_score': 0.01715334829556097,
#   'Iwcss': 0.0,
#   'Isep': 0.0,
#   'Idistcc': 0.0,
#   'Idens': 0.0},
#  {'k': 7,
#   'method': 'ward',
#   'split': 'H1',
#   'silhouette_score': 0.036005957747354954,
#   'Iwcss': 68156.02510745364,
#   'Isep': 6.422427673044486,
#   'Idistcc': 6.534804765251535,
#   'Idens': 1.354606259259077},
#  {'k': 7,
#   'method': 'ward',
#   'split': 'H2',
#   'silhouette_score': 0.07024156312935265,
#   'Iwcss': 64964.397829086825,
#   'Isep': 6.608809256367204,
#   'Idistcc': 6.471440050581448,
#   'Idens': 1.3065000065349575},
#  {'k': 7,
#   'method': 'kmeans_pca',
#   'split': 'H1',
#   'silhouette_score': 0.33266543056840914,
#   'Iwcss': 3746.8973302497843,
#   'Isep': 3.999598416020191,
#   'Idistcc': 1.3651303284561498,
#   'Idens': 0.6472953662360822},
#  {'k': 7,
#   'method': 'kmeans_pca',
#   'split': 'H2',
#   'silhouette_score': 0.3326650392404131,
#   'Iwcss': 3746.8984472191646,
#   'Isep': 3.9995984798625495,
#   'Idistcc': 1.3651306925811735,
#   'Idens': 0.6472954853055234},
#  {'k': 7,
#   'method': 'kmedoids_pca',
#   'split': 'H1',
#   'silhouette_score': 0.3166311682270372,
#   'Iwcss': 3801.7893212717468,
#   'Isep': 3.7697271572932385,
#   'Idistcc': 1.3360997764699962,
#   'Idens': 0.6291776434548859},
#  {'k': 7,
#   'method': 'kmedoids_pca',
#   'split': 'H2',
#   'silhouette_score': 0.316630997491381,
#   'Iwcss': 0.0,
#   'Isep': 0.0,
#   'Idistcc': 0.0,
#   'Idens': 0.0},
#  {'k': 7,
#   'method': 'ward_pca',
#   'split': 'H1',
#   'silhouette_score': 0.2835845521991721,
#   'Iwcss': 4300.30169564002,
#   'Isep': 3.9245263353804245,
#   'Idistcc': 1.431140080129765,
#   'Idens': 0.7305298539026623},
#  {'k': 7,
#   'method': 'ward_pca',
#   'split': 'H2',
#   'silhouette_score': 0.3071534299884943,
#   'Iwcss': 3996.7880681077495,
#   'Isep': 4.016623739535653,
#   'Idistcc': 1.3915943189114213,
#   'Idens': 0.6949874516186197},
#  {'k': 8,
#   'method': 'kmeans',
#   'split': 'H1',
#   'silhouette_score': 0.045223205960116884,
#   'Iwcss': 63593.02442301703,
#   'Isep': 5.219131553822974,
#   'Idistcc': 5.88375982079756,
#   'Idens': 1.4818227279468943},
#  {'k': 8,
#   'method': 'kmeans',
#   'split': 'H2',
#   'silhouette_score': 0.045223205960116884,
#   'Iwcss': 63593.02442301703,
#   'Isep': 5.219131553822974,
#   'Idistcc': 5.88375982079756,
#   'Idens': 1.4818227279468943},
#  {'k': 8,
#   'method': 'kmedoids',
#   'split': 'H1',
#   'silhouette_score': 0.010234164878146657,
#   'Iwcss': 67884.18898443949,
#   'Isep': 3.621093586427394,
#   'Idistcc': 5.826425043206101,
#   'Idens': 1.6345801090298047},
#  {'k': 8,
#   'method': 'kmedoids',
#   'split': 'H2',
#   'silhouette_score': 0.010234164878146657,
#   'Iwcss': 0.0,
#   'Isep': 0.0,
#   'Idistcc': 0.0,
#   'Idens': 0.0},
#  {'k': 8,
#   'method': 'ward',
#   'split': 'H1',
#   'silhouette_score': 0.0436720253642085,
#   'Iwcss': 66617.68838346386,
#   'Isep': 6.7915411973656,
#   'Idistcc': 6.356152694357143,
#   'Idens': 1.3695839479733876},
#  {'k': 8,
#   'method': 'ward',
#   'split': 'H2',
#   'silhouette_score': 0.07762390598097886,
#   'Iwcss': 63414.0363431973,
#   'Isep': 6.94211048644711,
#   'Idistcc': 6.3211679458415055,
#   'Idens': 1.3362037609505983},
#  {'k': 8,
#   'method': 'kmeans_pca',
#   'split': 'H1',
#   'silhouette_score': 0.32183926748691255,
#   'Iwcss': 3337.519853347991,
#   'Isep': 4.094779020776219,
#   'Idistcc': 1.2807386692256264,
#   'Idens': 0.6137442906590599},
#  {'k': 8,
#   'method': 'kmeans_pca',
#   'split': 'H2',
#   'silhouette_score': 0.32183949664333555,
#   'Iwcss': 3337.5181288777735,
#   'Isep': 4.0947794170469205,
#   'Idistcc': 1.2807384196339409,
#   'Idens': 0.6137439571449086},
#  {'k': 8,
#   'method': 'kmedoids_pca',
#   'split': 'H1',
#   'silhouette_score': 0.3096261673186793,
#   'Iwcss': 3424.024286395689,
#   'Isep': 3.8673672710437526,
#   'Idistcc': 1.256723859172418,
#   'Idens': 0.6003708058487486},
#  {'k': 8,
#   'method': 'kmedoids_pca',
#   'split': 'H2',
#   'silhouette_score': 0.30962573640628266,
#   'Iwcss': 0.0,
#   'Isep': 0.0,
#   'Idistcc': 0.0,
#   'Idens': 0.0},
#  {'k': 8,
#   'method': 'ward_pca',
#   'split': 'H1',
#   'silhouette_score': 0.28674626091109406,
#   'Iwcss': 3822.8000835363555,
#   'Isep': 4.481353735805541,
#   'Idistcc': 1.3194330843399593,
#   'Idens': 0.6623933829897634},
#  {'k': 8,
#   'method': 'ward_pca',
#   'split': 'H2',
#   'silhouette_score': 0.31060240377474957,
#   'Iwcss': 3526.769860031886,
#   'Isep': 4.408493876988448,
#   'Idistcc': 1.313225652557079,
#   'Idens': 0.6374226427684988},
#  {'k': 9,
#   'method': 'kmeans',
#   'split': 'H1',
#   'silhouette_score': 0.042257323736674464,
#   'Iwcss': 62808.31369743319,
#   'Isep': 5.293507921703409,
#   'Idistcc': 5.883442178522543,
#   'Idens': 1.478214309310005},
#  {'k': 9,
#   'method': 'kmeans',
#   'split': 'H2',
#   'silhouette_score': 0.042257323736674464,
#   'Iwcss': 62808.31369743319,
#   'Isep': 5.293507921703409,
#   'Idistcc': 5.883442178522543,
#   'Idens': 1.478214309310005},
#  {'k': 9,
#   'method': 'kmedoids',
#   'split': 'H1',
#   'silhouette_score': 0.016757071986467316,
#   'Iwcss': 66324.52844227148,
#   'Isep': 4.157451995793531,
#   'Idistcc': 5.832818365516466,
#   'Idens': 1.5786638916844495},
#  {'k': 9,
#   'method': 'kmedoids',
#   'split': 'H2',
#   'silhouette_score': 0.016757071986467316,
#   'Iwcss': 0.0,
#   'Isep': 0.0,
#   'Idistcc': 0.0,
#   'Idens': 0.0},
#  {'k': 9,
#   'method': 'ward',
#   'split': 'H1',
#   'silhouette_score': 0.04999154580391456,
#   'Iwcss': 65093.666807454414,
#   'Isep': 7.416112132453281,
#   'Idistcc': 6.198287668238046,
#   'Idens': 1.384365532013091},
#  {'k': 9,
#   'method': 'ward',
#   'split': 'H2',
#   'silhouette_score': 0.08363093329800322,
#   'Iwcss': 61915.289275984454,
#   'Isep': 7.532901081162692,
#   'Idistcc': 6.165888228538968,
#   'Idens': 1.3391745666765398},
#  {'k': 9,
#   'method': 'kmeans_pca',
#   'split': 'H1',
#   'silhouette_score': 0.3253192314765225,
#   'Iwcss': 2976.457733938856,
#   'Isep': 4.391381863698561,
#   'Idistcc': 1.2468078647738832,
#   'Idens': 0.5700174195001402},
#  {'k': 9,
#   'method': 'kmeans_pca',
#   'split': 'H2',
#   'silhouette_score': 0.3253194822130017,
#   'Iwcss': 2976.4563319169392,
#   'Isep': 4.391382153513359,
#   'Idistcc': 1.2468079314351264,
#   'Idens': 0.5700170092857992},
#  {'k': 9,
#   'method': 'kmedoids_pca',
#   'split': 'H1',
#   'silhouette_score': 0.3160779870901155,
#   'Iwcss': 3096.6086728980817,
#   'Isep': 3.908425362238,
#   'Idistcc': 1.1773906424537175,
#   'Idens': 0.5637380631990968},
#  {'k': 9,
#   'method': 'kmedoids_pca',
#   'split': 'H2',
#   'silhouette_score': 0.3161979309859901,
#   'Iwcss': 0.0,
#   'Isep': 0.0,
#   'Idistcc': 0.0,
#   'Idens': 0.0},
#  {'k': 9,
#   'method': 'ward_pca',
#   'split': 'H1',
#   'silhouette_score': 0.2850276977843449,
#   'Iwcss': 3380.7700018337996,
#   'Isep': 4.4595889673872975,
#   'Idistcc': 1.2242179126576078,
#   'Idens': 0.603876181985264},
#  {'k': 9,
#   'method': 'ward_pca',
#   'split': 'H2',
#   'silhouette_score': 0.3221306499856917,
#   'Iwcss': 3067.9994370290397,
#   'Isep': 4.386375751043062,
#   'Idistcc': 1.2282882377696809,
#   'Idens': 0.5904980363336451},
#  {'k': 10,
#   'method': 'kmeans',
#   'split': 'H1',
#   'silhouette_score': 0.044160268185523786,
#   'Iwcss': 61473.1573917371,
#   'Isep': 5.417848959392099,
#   'Idistcc': 5.810378182109122,
#   'Idens': 1.420766548467736},
#  {'k': 10,
#   'method': 'kmeans',
#   'split': 'H2',
#   'silhouette_score': 0.044160268185523786,
#   'Iwcss': 61473.1573917371,
#   'Isep': 5.417848959392099,
#   'Idistcc': 5.810378182109122,
#   'Idens': 1.420766548467736},
#  {'k': 10,
#   'method': 'kmedoids',
#   'split': 'H1',
#   'silhouette_score': 0.022266840799194224,
#   'Iwcss': 64763.18432741793,
#   'Isep': 4.771716081690628,
#   'Idistcc': 5.8406502344359925,
#   'Idens': 1.5431678985664476},
#  {'k': 10,
#   'method': 'kmedoids',
#   'split': 'H2',
#   'silhouette_score': 0.022266840799194224,
#   'Iwcss': 0.0,
#   'Isep': 0.0,
#   'Idistcc': 0.0,
#   'Idens': 0.0},
#  {'k': 10,
#   'method': 'ward',
#   'split': 'H1',
#   'silhouette_score': 0.04647984342792651,
#   'Iwcss': 63592.99089728132,
#   'Isep': 7.529177062554833,
#   'Idistcc': 6.144070279363345,
#   'Idens': 1.3414946852110132},
#  {'k': 10,
#   'method': 'ward',
#   'split': 'H2',
#   'silhouette_score': 0.08424391780662148,
#   'Iwcss': 60620.86556366034,
#   'Isep': 7.631937058047412,
#   'Idistcc': 6.1165406449748785,
#   'Idens': 1.3088551727405937},
#  {'k': 10,
#   'method': 'kmeans_pca',
#   'split': 'H1',
#   'silhouette_score': 0.3233994731738231,
#   'Iwcss': 2700.301373534998,
#   'Isep': 4.467017463855211,
#   'Idistcc': 1.1912473173174427,
#   'Idens': 0.5487512780822752},
#  {'k': 10,
#   'method': 'kmeans_pca',
#   'split': 'H2',
#   'silhouette_score': 0.32339963988737047,
#   'Iwcss': 2700.300553611212,
#   'Isep': 4.467017542623424,
#   'Idistcc': 1.191247046699187,
#   'Idens': 0.5487513033910432},
#  {'k': 10,
#   'method': 'kmedoids_pca',
#   'split': 'H1',
#   'silhouette_score': 0.3219664124089468,
#   'Iwcss': 2809.3817502062984,
#   'Isep': 4.056986350395878,
#   'Idistcc': 1.13641287424606,
#   'Idens': 0.5522685120694079},
#  {'k': 10,
#   'method': 'kmedoids_pca',
#   'split': 'H2',
#   'silhouette_score': 0.3219660173363921,
#   'Iwcss': 0.0,
#   'Isep': 0.0,
#   'Idistcc': 0.0,
#   'Idens': 0.0},
#  {'k': 10,
#   'method': 'ward_pca',
#   'split': 'H1',
#   'silhouette_score': 0.2887215586797299,
#   'Iwcss': 3042.035748447196,
#   'Isep': 4.544990308199437,
#   'Idistcc': 1.205287761213672,
#   'Idens': 0.5974649452207914},
#  {'k': 10,
#   'method': 'ward_pca',
#   'split': 'H2',
#   'silhouette_score': 0.32074146349280336,
#   'Iwcss': 2829.4965971999577,
#   'Isep': 4.4907575530652535,
#   'Idistcc': 1.1895355412053017,
#   'Idens': 0.5795081918690388}]

# %%
for k in range(2, 11):
    print("---"*10)
    print(f"k == {k}")
    input_dim = X_h1.shape[1]
    latent_dim = 10

    ae = AutoEncoder(input_dim, latent_dim)
    criterion = nn.MSELoss()
    optimizer = optim.Adam(ae.parameters(), lr=1e-3)

    print("AE training...")
    # AE pretrain on H1
    for epoch in range(3000):
        optimizer.zero_grad()
        out = ae(X_h1_tensor)
        loss = criterion(out, X_h1_tensor)
        loss.backward()
        optimizer.step()        
        if epoch % 500 == 0:
            print(f"Epoch: {epoch}")

    # init clusters using H1 latent
    z_h1 = ae.encoder(X_h1_tensor).detach().numpy()
    km = KMeans(n_clusters=k, random_state=42).fit(z_h1)
    init_centers = torch.tensor(km.cluster_centers_, dtype=torch.float32)

    dec = DEC(ae.encoder, init_centers.clone())
    dec_opt = optim.Adam(dec.parameters(), lr=1e-3)

    print("DEC training...")
    # DEC train on H1
    for epoch in range(3000): 
        q = dec(X_h1_tensor)
        p = target_distribution(q.detach())
        kl = torch.nn.functional.kl_div(q.log(), p, reduction="batchmean")
        dec_opt.zero_grad()
        kl.backward()
        dec_opt.step()
        if epoch % 500 == 0:
            print(f"Epoch: {epoch}")

    # ===== evaluate on H1 =====
    with torch.no_grad():
        z_h1_eval = dec.encoder(X_h1_tensor).cpu().numpy()
        q_h1 = dec(X_h1_tensor)
        y_h1_eval = torch.argmax(q_h1, dim=1).cpu().numpy()

    append_eval(k, "dec", z_h1_eval, y_h1_eval, "H1")

    # ===== evaluate on H2 =====
    with torch.no_grad():
        z_h2_eval = dec.encoder(X_h2_tensor).cpu().numpy()
        q_h2 = dec(X_h2_tensor)
        y_h2_eval = torch.argmax(q_h2, dim=1).cpu().numpy()

    append_eval(k, "dec", z_h2_eval, y_h2_eval, "H2")
# Out:
# ------------------------------
# k == 2
# AE training...
# Epoch: 0
# Epoch: 500
# Epoch: 1000
# Epoch: 1500
# Epoch: 2000
# Epoch: 2500
# DEC training...
# Epoch: 0
# Epoch: 500
# Epoch: 1000
# Epoch: 1500
# Epoch: 2000
# Epoch: 2500
# ------------------------------
# k == 3
# AE training...
# Epoch: 0
# Epoch: 500
# Epoch: 1000
# Epoch: 1500
# Epoch: 2000
# Epoch: 2500
# DEC training...
# Epoch: 0
# Epoch: 500
# Epoch: 1000
# Epoch: 1500
# Epoch: 2000
# Epoch: 2500
# ------------------------------
# k == 4
# AE training...
# Epoch: 0
# Epoch: 500
# Epoch: 1000
# Epoch: 1500
# Epoch: 2000
# Epoch: 2500
# DEC training...
# Epoch: 0
# Epoch: 500
# Epoch: 1000
# Epoch: 1500
# Epoch: 2000
# Epoch: 2500
# ------------------------------
# k == 5
# AE training...
# Epoch: 0
# Epoch: 500
# Epoch: 1000
# Epoch: 1500
# Epoch: 2000
# Epoch: 2500
# DEC training...
# Epoch: 0
# Epoch: 500
# Epoch: 1000
# Epoch: 1500
# Epoch: 2000
# Epoch: 2500
# ------------------------------
# k == 6
# AE training...
# Epoch: 0
# Epoch: 500
# Epoch: 1000
# Epoch: 1500
# Epoch: 2000
# Epoch: 2500
# DEC training...
# Epoch: 0
# Epoch: 500
# Epoch: 1000
# Epoch: 1500
# Epoch: 2000
# Epoch: 2500
# ------------------------------
# k == 7
# AE training...
# Epoch: 0
# Epoch: 500
# Epoch: 1000
# Epoch: 1500
# Epoch: 2000
# Epoch: 2500
# DEC training...
# Epoch: 0
# Epoch: 500
# Epoch: 1000
# Epoch: 1500
# Epoch: 2000
# Epoch: 2500
# ------------------------------
# k == 8
# AE training...
# Epoch: 0
# Epoch: 500
# Epoch: 1000
# Epoch: 1500
# Epoch: 2000
# Epoch: 2500
# DEC training...
# Epoch: 0
# Epoch: 500
# Epoch: 1000
# Epoch: 1500
# Epoch: 2000
# Epoch: 2500
# ------------------------------
# k == 9
# AE training...
# Epoch: 0
# Epoch: 500
# Epoch: 1000
# Epoch: 1500
# Epoch: 2000
# Epoch: 2500
# DEC training...
# Epoch: 0
# Epoch: 500
# Epoch: 1000
# Epoch: 1500
# Epoch: 2000
# Epoch: 2500
# ------------------------------
# k == 10
# AE training...
# Epoch: 0
# Epoch: 500
# Epoch: 1000
# Epoch: 1500
# Epoch: 2000
# Epoch: 2500
# DEC training...
# Epoch: 0
# Epoch: 500
# Epoch: 1000
# Epoch: 1500
# Epoch: 2000
# Epoch: 2500

# %%
def minmax_normalize(val, min_val, max_val, larger_is_better):
    if np.isclose(max_val - min_val, 0):
        return 1.0
    score = (val - min_val) / (max_val - min_val)
    return score if larger_is_better else 1 - score

results_normalized = []

for split_tag in ["H1", "H2"]:
    rows = [r for r in results if r["split"] == split_tag]

    index_min = {
        'Iwcss': min(row['Iwcss'] for row in rows),
        'Isep': min(row['Isep'] for row in rows),
        'Idistcc': min(row['Idistcc'] for row in rows),
        'Idens': min(row['Idens'] for row in rows),
    }
    index_max = {
        'Iwcss': max(row['Iwcss'] for row in rows),
        'Isep': max(row['Isep'] for row in rows),
        'Idistcc': max(row['Idistcc'] for row in rows),
        'Idens': max(row['Idens'] for row in rows),
    }

    for row in rows:
        Iwcss_m = minmax_normalize(row['Iwcss'], index_min['Iwcss'], index_max['Iwcss'], larger_is_better=False)
        Isep_m  = minmax_normalize(row['Isep'],  index_min['Isep'],  index_max['Isep'],  larger_is_better=True)
        Idistcc_m = minmax_normalize(row['Idistcc'], index_min['Idistcc'], index_max['Idistcc'], larger_is_better=False)
        Idens_m   = minmax_normalize(row['Idens'],   index_min['Idens'],   index_max['Idens'],   larger_is_better=False)

        AC1_m = (Iwcss_m + Isep_m + Idistcc_m + Idens_m) / 4
        AC2_m = (1 * Iwcss_m + 0.5 * Isep_m + 1 * Idistcc_m + 0.25 * Idens_m) / 2.75

        results_normalized.append({
            'k': row['k'],
            'method': row['method'],
            'split': row['split'],
            'silhouette_score': row['silhouette_score'],
            'AC1': AC1_m,
            'AC2': AC2_m
        })

df = pd.DataFrame(results_normalized)

# %%
# should be: 7 methods * 9 k-values * 2 splits = 126 rows
df.groupby(["method","split"])["k"].count().sort_values()
# Out:
# method        split
# dec           H1       9
#               H2       9
# kmeans        H1       9
#               H2       9
# kmeans_pca    H1       9
#               H2       9
# kmedoids      H1       9
#               H2       9
# kmedoids_pca  H1       9
#               H2       9
# ward          H1       9
#               H2       9
# ward_pca      H1       9
#               H2       9
# Name: k, dtype: int64

# %%
# method mapping
old_methods = ['dec', 'kmeans', 'kmeans_pca', 'kmedoids', 'kmedoids_pca', 'ward', 'ward_pca']
new_methods = ['DEC (proposed method)', 'K-Means', 'K-Means_with_pca', 'K-Medoids', 'K-Medoids_with_pca', 'Ward', 'Ward_with_pca']
method_map = dict(zip(old_methods, new_methods))
df['method'] = df['method'].map(method_map)

# %%
# Store traditiional_results
traditiional_results = []

from sklearn.metrics import pairwise_distances_argmin

def predict_via_centroids(X_train, y_train, X_eval):
    centers = np.vstack([X_train[y_train == c].mean(axis=0) for c in np.unique(y_train)])
    return pairwise_distances_argmin(X_eval, centers)

def predict_kmedoids_generalizable(model, X_h1, y_h1, X_h2):
    # Use H1 centroids as representatives for stable cross-split assignment
    return predict_via_centroids(X_h1, y_h1, X_h2)

def append_eval(k, method, X_eval, y_eval, split_tag):
    sil = silhouette_score(X_eval, y_eval)
    Iwcss, Isep, Idistcc, Idens = compute_indices(X_eval, y_eval)
    traditiional_results.append({
        "k": k,
        "method": method,
        "split": split_tag,
        "silhouette_score": sil,
        "Iwcss": Iwcss,
        "Isep": Isep,
        "Idistcc": Idistcc,
        "Idens": Idens
    })

for k in range(2, 11):
    clusterings = {
        "kmeans": KMeans(n_clusters=k, random_state=42),
        "kmedoids": KMedoids(n_clusters=k, metric="euclidean", init="random", max_iter=300, random_state=42),
        "ward": AgglomerativeClustering(n_clusters=k, linkage="ward"),
    }

    # ====== RAW space (scaled) ======
    for method_name, model in clusterings.items():
        y_h1 = model.fit_predict(X_h1)

        # Evaluate on H1
        append_eval(k, method_name, X_h1, y_h1, "H1")

        # Labels for H2 (cross-split comparable)
        if method_name == "kmedoids":
            y_h2 = predict_kmedoids_generalizable(model, X_h1, y_h1, X_h2)
        elif hasattr(model, "predict"):
            y_h2 = model.predict(X_h2)
        else:
            y_h2 = predict_via_centroids(X_h1, y_h1, X_h2)

        # Evaluate on H2
        append_eval(k, method_name, X_h2, y_h2, "H2")

    # ====== PCA space ======
    for method_name, model in clusterings.items():
        y_h1 = model.fit_predict(X_h1_pca)

        append_eval(k, f"{method_name}_pca", X_h1_pca, y_h1, "H1")

        if method_name == "kmedoids":
            y_h2 = predict_kmedoids_generalizable(model, X_h1_pca, y_h1, X_h2_pca)
        elif hasattr(model, "predict"):
            y_h2 = model.predict(X_h2_pca)
        else:
            y_h2 = predict_via_centroids(X_h1_pca, y_h1, X_h2_pca)

        append_eval(k, f"{method_name}_pca", X_h2_pca, y_h2, "H2")

def minmax_normalize(val, min_val, max_val, larger_is_better):
    if np.isclose(max_val - min_val, 0):
        return 1.0
    score = (val - min_val) / (max_val - min_val)
    return score if larger_is_better else 1 - score

traditiional_results_normalized_trad = []

for split_tag in ["H1", "H2"]:
    rows = [r for r in traditiional_results if r["split"] == split_tag]

    index_min = {
        'Iwcss': min(row['Iwcss'] for row in rows),
        'Isep': min(row['Isep'] for row in rows),
        'Idistcc': min(row['Idistcc'] for row in rows),
        'Idens': min(row['Idens'] for row in rows),
    }
    index_max = {
        'Iwcss': max(row['Iwcss'] for row in rows),
        'Isep': max(row['Isep'] for row in rows),
        'Idistcc': max(row['Idistcc'] for row in rows),
        'Idens': max(row['Idens'] for row in rows),
    }

    for row in rows:
        Iwcss_m = minmax_normalize(row['Iwcss'], index_min['Iwcss'], index_max['Iwcss'], larger_is_better=False)
        Isep_m  = minmax_normalize(row['Isep'],  index_min['Isep'],  index_max['Isep'],  larger_is_better=True)
        Idistcc_m = minmax_normalize(row['Idistcc'], index_min['Idistcc'], index_max['Idistcc'], larger_is_better=False)
        Idens_m   = minmax_normalize(row['Idens'],   index_min['Idens'],   index_max['Idens'],   larger_is_better=False)

        AC1_m = (Iwcss_m + Isep_m + Idistcc_m + Idens_m) / 4
        AC2_m = (1 * Iwcss_m + 0.5 * Isep_m + 1 * Idistcc_m + 0.25 * Idens_m) / 2.75

        traditiional_results_normalized_trad.append({
            'k': row['k'],
            'method': row['method'],
            'split': row['split'],
            'silhouette_score': row['silhouette_score'],
            'AC1': AC1_m,
            'AC2': AC2_m
        })

df_trad = pd.DataFrame(traditiional_results_normalized_trad)

# %%
df_dec = df[df['method'] == 'DEC (proposed method)']
df = pd.concat([df_trad,df_dec])

# method mapping
df = df[df.method.isin(['kmeans', 'ward', 'kmedoids', 'DEC (proposed method)'])].copy()
old_methods = ['DEC (proposed method)', 'kmeans', 'kmedoids', 'ward'] #,'kmeans_pca',  'kmedoids_pca',  'ward_pca']
new_methods = ['DEC (proposed method)', 'K-Means', 'K-Medoids', 'Ward'] #,'K-Means_with_pca',  'K-Medoids_with_pca',  'Ward_with_pca']
method_map = dict(zip(old_methods, new_methods))
df['method'] = df['method'].map(method_map)

df['k'] = df['k'].astype(int)
for col in ['silhouette_score', 'AC1', 'AC2']:
    df[col] = df[col].astype(float)

methods = new_methods
#df

# %%
## method mapping
#df = df[df.method.isin(['kmeans', 'ward', 'kmedoids', 'DEC (proposed method)'])].copy()
#old_methods = ['DEC (proposed method)', 'kmeans', 'kmedoids', 'ward'] #,'kmeans_pca',  'kmedoids_pca',  'ward_pca']
#new_methods = ['DEC (proposed method)', 'K-Means', 'K-Medoids', 'Ward'] #,'K-Means_with_pca',  'K-Medoids_with_pca',  'Ward_with_pca']
#method_map = dict(zip(old_methods, new_methods))
#df['method'] = df['method'].map(method_map)
#
#df['k'] = df['k'].astype(int)
#for col in ['silhouette_score', 'AC1', 'AC2']:
#    df[col] = df[col].astype(float)
#
#methods = new_methods

base_colors = {
    'DEC (proposed method)': '#d62728',
    'K-Means': '#1f77b4',
    #'K-Means_with_pca': '#1f77b4',
    'K-Medoids': '#ff7f0e',
    #'K-Medoids_with_pca': '#ff7f0e',
    'Ward': '#2ca02c',
    #'Ward_with_pca': '#2ca02c'
}

split_alpha = {"H1": 0.75, "H2": 1.0}
split_ls    = {"H1": "--", "H2": "-"}

fig, axs = plt.subplots(3, 1, figsize=(12, 18), sharex=True)
metrics = ['silhouette_score', 'AC1', 'AC2']
ylabels = ['Silhouette Score', 'A(C)1', 'A(C)2']

for ax, metric, ylabel in zip(axs, metrics, ylabels):
    for method in methods:
        for split_tag in ["H1", "H2"]:
            subset = df[(df['method'] == method) & (df['split'] == split_tag)].sort_values("k")
            x = subset['k'].to_numpy()
            y = subset[metric].to_numpy()

            ax.plot(
                x, y,
                label=f"{method} ({split_tag})",
                color=base_colors[method],
                alpha=split_alpha[split_tag],
                linestyle=split_ls[split_tag],
                linewidth=2.2 if (method == 'DEC (proposed method)' and split_tag == "H2") else 1.6
            )
            ax.scatter(x, y, color=base_colors[method], alpha=split_alpha[split_tag], s=35)

            if method == 'DEC (proposed method)':
                if split_tag == 'H1':
                    ax.text(x[-1] + 0.04, y[-1]+0.02, f'DEC({split_tag})', color=base_colors[method],
                        fontsize=8, va='center') #fontweight='bold', va='center')
                else:
                    ax.text(x[-1] + 0.04, y[-1]-0.02, f'DEC({split_tag})', color=base_colors[method],
                        fontsize=8, va='center') #fontweight='bold', va='center')
            

    ax.set_ylabel(ylabel, fontsize=12)
    ax.grid(True)

axs[-1].set_xlabel('Number of Clusters (k)', fontsize=12)
fig.suptitle("1st Half (dashed) vs 2nd Half (solid) - Negative Transition Phase", fontsize=16, fontweight='bold', y=.95)

axs[0].legend(loc='upper center', bbox_to_anchor=(0.5, 1.22), ncol=3, fontsize=9, frameon=False)
plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()

# %%
pd.DataFrame(results).to_excel("results_ball_loss.xlsx")
